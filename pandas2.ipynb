# %%
import pandas as pd

# %% [raw]
# #methods to create dataframe
# 1 nested list
# 2 list of dict
# 3 dict of list

# %%
li =[ ["swetha",21,"btech" ],
      ["nandana",20,"bca"],
      ["manu",19,"bba"],
      ["vinod",11,"bcom"]
    ]
df = pd.DataFrame(li,columns =['name','age','dept'])
(df)
# Out:
#       name  age   dept
# 0   swetha   21  btech
# 1  nandana   20    bca
# 2     manu   19    bba
# 3    vinod   11   bcom

# %%
print(df.shape)
print(df.size)
print(df.ndim)
# Out:
# (4, 3)
# 12
# 2

# %%
#column name
df = pd.DataFrame(li, columns = ['name','age','dpt'])
df
# Out:
#       name  age    dpt
# 0   swetha   21  btech
# 1  nandana   20    bca
# 2     manu   19    bba
# 3    vinod   11   bcom

# %%
#dict of list
dic = {"Name":["Anu","Adhil","kavya","vinod"],
        "roll no" :[10,12,23,45],
        "Batch":["Bca","bcom","bba","ba"]}
df=pd.DataFrame(dic)
df
# Out:
#     Name  roll no Batch
# 0    Anu       10   Bca
# 1  Adhil       12  bcom
# 2  kavya       23   bba
# 3  vinod       45    ba

# %%
#list of dict
lis =[
    {'name':'Anu','roll no':10,'batch':'bca'},
     {'name': 'Manu','roll no':11,'batch':'bba'},
    {'name':'Vinod','roll no': 12,'batch':'BA'}
]
df= pd.DataFrame(lis)
df
# Out:
#     name  roll no batch
# 0    Anu       10   bca
# 1   Manu       11   bba
# 2  Vinod       12    BA

# %%
#nested list
li =[ [1,"Swetha","developer",50000],
      [2,"nandana","data analyst",650000],
      [3,"manu","Hr",250000],
      [4,"vinod","designer",450000]
    ]
df = pd.DataFrame(li,columns =["empid","empname","designation","salary"])
(df)
# Out:
#    empid  empname   designation  salary
# 0      1   Swetha     developer   50000
# 1      2  nandana  data analyst  650000
# 2      3     manu            Hr  250000
# 3      4    vinod      designer  450000

# %%
#dict of list
dic = {"empid" :[1,2,3,4],
        "empname":["swetha","nandana","manu","anu"],
        "designation":["data analyst","developer","Hr","designer"],
        "salary" :[50000,450000,60000,34000]}
df =pd.DataFrame(dic)
df
# Out:
#    empid  empname   designation  salary
# 0      1   swetha  data analyst   50000
# 1      2  nandana     developer  450000
# 2      3     manu            Hr   60000
# 3      4      anu      designer   34000

# %%
#list of dict
lis =[
    {'empid':1,'empname':'swetha','designation':'data analyst','salary':50000},
     {'empid':2,'empname':'nandana','designation':'developer','salary':45000},
    {'empid':3,'empname':'manu' ,'designation':'Hr','salary':56000},
    {'empid':4,'empname':'anu','designation':'Designer','salary':34000}
]
df= pd.DataFrame(lis)
df
# Out:
#    empid  empname   designation  salary
# 0      1   swetha  data analyst   50000
# 1      2  nandana     developer   45000
# 2      3     manu            Hr   56000
# 3      4      anu      Designer   34000

# %%
df.head(2)
# Out:
#    empid  empname   designation  salary
# 0      1   swetha  data analyst   50000
# 1      2  nandana     developer   45000

# %%
df.tail(2)
# Out:
#    empid empname designation  salary
# 2      3    manu          Hr   56000
# 3      4     anu    Designer   34000

# %%
df.columns
# Out:
# Index(['empid', 'empname', 'designation', 'salary'], dtype='str')

# %%
df.dtypes
# Out:
# empid          int64
# empname          str
# designation      str
# salary         int64
# dtype: object

# %%
df['empname'].dtypes
# Out:
# <StringDtype(storage='python', na_value=nan)>

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   empid        4 non-null      int64
#  1   empname      4 non-null      str
#  2   designation  4 non-null      str
#  3   salary       4 non-null      int64
# dtypes: int64(2), str(2)
# memory usage: 260.0 bytes

# %%
#statistical summary
df.describe()
# Out:
#           empid        salary
# count  4.000000      4.000000
# mean   2.500000  46250.000000
# std    1.290994   9322.910847
# min    1.000000  34000.000000
# 25%    1.750000  42250.000000
# 50%    2.500000  47500.000000
# 75%    3.250000  51500.000000
# max    4.000000  56000.000000

# %%
#including objects
df.describe(include ='object')
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_11988\3256468843.py:2: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   df.describe(include ='object')
#        empname   designation
# count        4             4
# unique       4             4
# top     swetha  data analyst
# freq         1             1

# %%
df['empname']
# Out:
# 0     swetha
# 1    nandana
# 2       manu
# 3        anu
# Name: empname, dtype: str

# %%
df[['empname','designation']]
# Out:
#    empname   designation
# 0   swetha  data analyst
# 1  nandana     developer
# 2     manu            Hr
# 3      anu      Designer

# %%
#select row using loc -label based
df.loc[1]
# Out:
# empid                  2
# empname          nandana
# designation    developer
# salary             45000
# Name: 1, dtype: object

# %%
#use both integer based
df.iloc[0:3][['salary']]
# Out:
#    salary
# 0   50000
# 1   45000
# 2   56000

# %%
print(df.iloc[1])
# Out:
# empid                  2
# empname          nandana
# designation    developer
# salary             45000
# Name: 1, dtype: object

# %%
#to add new column
df["points"]=[122,234,190,111]
print(df)
# Out:
#    empid  empname   designation  salary  points
# 0      1   swetha  data analyst   50000     122
# 1      2  nandana     developer   45000     234
# 2      3     manu            Hr   56000     190
# 3      4      anu      Designer   34000     111

# %%
#update a value using index
df.iloc[3,4] = 55
print(df)
# Out:
#    empid  empname   designation  salary  points
# 0      1   swetha  data analyst   50000     122
# 1      2  nandana     developer   45000     234
# 2      3     manu            Hr   56000     190
# 3      4      anu      Designer   34000      55

# %%
df.loc[1,'points'] = 670
df
# Out:
#    empid  empname   designation  salary  points
# 0      1   swetha  data analyst   50000     122
# 1      2  nandana     developer   45000     670
# 2      3     manu            Hr   56000     190
# 3      4      anu      Designer   34000      55

# %%
#drop is used to delete columns,axis 1 denotes columns,inplace is used to permanantly delete those columns)
df.drop('points',axis=1,inplace = True)
df
# Out:
#    empid  empname   designation  salary
# 0      1   swetha  data analyst   50000
# 1      2  nandana     developer   45000
# 2      3     manu            Hr   56000
# 3      4      anu      Designer   34000

# %%
df.drop(2)
# Out:
#    empid  empname   designation  salary
# 0      1   swetha  data analyst   50000
# 1      2  nandana     developer   45000
# 3      4      anu      Designer   34000

# %%
#filtering data
df1 =df[df['empid']<3]
df1
# Out:
#    empid  empname   designation  salary
# 0      1   swetha  data analyst   50000
# 1      2  nandana     developer   45000

# %%
#sorting data based on empname
df.sort_values(by ='empname')
# Out:
#    empid  empname   designation  salary
# 3      4      anu      Designer   34000
# 2      3     manu            Hr   56000
# 1      2  nandana     developer   45000
# 0      1   swetha  data analyst   50000

# %%
#for descending order sorting
df.sort_values("empname", ascending= False)
# Out:
#    empid  empname   designation  salary
# 0      1   swetha  data analyst   50000
# 1      2  nandana     developer   45000
# 2      3     manu            Hr   56000
# 3      4      anu      Designer   34000

# %%
pip install openpyxl
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 26.0.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
df=pd.read_excel(r"C:\Users\USER\Downloads\gender.xlsx")
df
# Out:
#      PassengerId  Survived
# 0            892         0
# 1            893         1
# 2            894         0
# 3            895         0
# 4            896         1
# ..           ...       ...
# 413         1305         0
# 414         1306         1
# 415         1307         0
# 416         1308         0
# 417         1309         0
#
# [418 rows x 2 columns]

# %%
df.drop([1,5,8])
# Out:
#      PassengerId  Survived
# 0            892         0
# 2            894         0
# 3            895         0
# 4            896         1
# 6            898         1
# ..           ...       ...
# 413         1305         0
# 414         1306         1
# 415         1307         0
# 416         1308         0
# 417         1309         0
#
# [415 rows x 2 columns]

# %%
#sort row
df2 = df[df['Survived']>0]
df2
# Out:
#      PassengerId  Survived
# 1            893         1
# 4            896         1
# 6            898         1
# 8            900         1
# 12           904         1
# ..           ...       ...
# 409         1301         1
# 410         1302         1
# 411         1303         1
# 412         1304         1
# 414         1306         1
#
# [152 rows x 2 columns]

# %%
df2.reset_index(drop=True)
# Out:
#      PassengerId  Survived
# 0            893         1
# 1            896         1
# 2            898         1
# 3            900         1
# 4            904         1
# ..           ...       ...
# 147         1301         1
# 148         1302         1
# 149         1303         1
# 150         1304         1
# 151         1306         1
#
# [152 rows x 2 columns]

# %%
df.to_csv("output.csv")

# %%
df = pd.read_csv(r"C:\Users\USER\Downloads\fifa_world_cup_2026_player_performance-selected-columns.csv")
df
# Out:
#       player_id       player_name  age nationality   team  jersey_number  \
# 0        P00055        Rodri Fati   26     Spanish  Spain              3
# 1        P00070   Ansu Le Normand   19     Spanish  Spain             18
# 2        P00066        Gavi Ramos   18     Spanish  Spain             14
# 3        P00073     Pedro Cubarsi   20     Spanish  Spain             21
# 4        P00059  Alvaro Oyarzabal   23     Spanish  Spain              7
# ...         ...               ...  ...         ...    ...            ...
# 54595    P00996       Amir Younis   28       Iraqi   Iraq              8
# 54596    P01006  Safaa Al-Khafaji   20       Iraqi   Iraq             18
# 54597    P01008     Ahmed Hussein   26       Iraqi   Iraq             20
# 54598    P00991     Ibrahim Mhawi   30       Iraqi   Iraq              3
# 54599    P00989  Mohannad Hussein   27       Iraqi   Iraq              1
#
#          position  height_cm  weight_kg preferred_foot
# ...

# %%
df.drop(['player_id','player_name','age'],axis =1,inplace = True)
df
# Out:
#       nationality   team  jersey_number    position  height_cm  weight_kg  \
# 0         Spanish  Spain              3  Goalkeeper        195         75
# 1         Spanish  Spain             18  Midfielder        178         75
# 2         Spanish  Spain             14  Midfielder        177         72
# 3         Spanish  Spain             21     Forward        182         74
# 4         Spanish  Spain              7    Defender        191         81
# ...           ...    ...            ...         ...        ...        ...
# 54595       Iraqi   Iraq              8    Defender        177         73
# 54596       Iraqi   Iraq             18  Midfielder        176         72
# 54597       Iraqi   Iraq             20  Midfielder        173         77
# 54598       Iraqi   Iraq              3  Goalkeeper        190         81
# 54599       Iraqi   Iraq              1  Goalkeeper        187         73
#
#       preferred_foot
# 0               Left
# 1              Right
# ...

# %%
df['team'].dtypes
# Out:
# <StringDtype(storage='python', na_value=nan)>

# %%
df.iloc[1:11][['team','position']]
# Out:
#      team    position
# 1   Spain  Midfielder
# 2   Spain  Midfielder
# 3   Spain     Forward
# 4   Spain    Defender
# 5   Spain  Midfielder
# 6   Spain    Defender
# 7   Spain     Forward
# 8   Spain    Defender
# 9   Spain     Forward
# 10  Spain  Midfielder

# %%
df.sort_values(by = 'jersey_number',ascending=False)
# Out:
#       nationality      team  jersey_number    position  height_cm  weight_kg  \
# 54558  Senegalese   Senegal             26     Forward        186         78
# 7         Spanish     Spain             26     Forward        182         72
# 21023    Nigerian   Nigeria             26     Forward        185         74
# 21002     Serbian    Serbia             26     Forward        170         72
# 47740      Qatari     Qatar             26     Forward        181         77
# ...           ...       ...            ...         ...        ...        ...
# 40897   Colombian  Colombia              1  Goalkeeper        192         85
# 40898     Italian     Italy              1  Goalkeeper        187         75
# 40870    Jamaican   Jamaica              1  Goalkeeper        190         77
# 48281    Tunisian   Tunisia              1  Goalkeeper        190         81
# 48282  Ecuadorian   Ecuador              1  Goalkeeper        185         74
#
#       preferred_foot
# 54558          Right
# ...

# %%
df.sort_values(by ='jersey_number').tail(1)
# Out:
#       nationality   team  jersey_number position  height_cm  weight_kg  \
# 15907     Chilean  Chile             26  Forward        175         76
#
#       preferred_foot
# 15907          Right

# %%
df.reset_index(drop=True)
# Out:
#       nationality   team  jersey_number    position  height_cm  weight_kg  \
# 0         Spanish  Spain              3  Goalkeeper        195         75
# 1         Spanish  Spain             18  Midfielder        178         75
# 2         Spanish  Spain             14  Midfielder        177         72
# 3         Spanish  Spain             21     Forward        182         74
# 4         Spanish  Spain              7    Defender        191         81
# ...           ...    ...            ...         ...        ...        ...
# 54595       Iraqi   Iraq              8    Defender        177         73
# 54596       Iraqi   Iraq             18  Midfielder        176         72
# 54597       Iraqi   Iraq             20  Midfielder        173         77
# 54598       Iraqi   Iraq              3  Goalkeeper        190         81
# 54599       Iraqi   Iraq              1  Goalkeeper        187         73
#
#       preferred_foot
# 0               Left
# 1              Right
# ...

# %%
df['position'].unique()
# Out:
# <StringArray>
# ['Goalkeeper', 'Midfielder', 'Forward', 'Defender']
# Length: 4, dtype: str

# %%
df['position'].nunique()
# Out:
# 4

# %%
df['position'].value_counts()
# Out:
# position
# Defender      18900
# Midfielder    16800
# Forward       12600
# Goalkeeper     6300
# Name: count, dtype: int64

# %%
df2 = df.loc[df['position']=='Defender']
df2
# Out:
#       nationality   team  jersey_number  position  height_cm  weight_kg  \
# 4         Spanish  Spain              7  Defender        191         81
# 6         Spanish  Spain              6  Defender        188         80
# 8         Spanish  Spain              4  Defender        176         78
# 14        Spanish  Spain              5  Defender        187         76
# 15        Spanish  Spain             10  Defender        175         73
# ...           ...    ...            ...       ...        ...        ...
# 54584       Iraqi   Iraq              7  Defender        188         84
# 54585       Iraqi   Iraq             11  Defender        187         80
# 54588       Iraqi   Iraq             10  Defender        190         78
# 54590       Iraqi   Iraq              6  Defender        180         78
# 54595       Iraqi   Iraq              8  Defender        177         73
#
#       preferred_foot
# 4               Left
# 6              Right
# 8               Left
# ...

# %%
df2 =df.loc[(df['position']=='Defender') & (df['jersey_number']>10)]
df2
# Out:
#          nationality          team  jersey_number  position  height_cm  \
# 17           Spanish         Spain             12  Defender        181
# 22           Spanish         Spain             11  Defender        183
# 35     South African  South Africa             11  Defender        190
# 41     South African  South Africa             12  Defender        184
# 53          Peruvian          Peru             11  Defender        187
# ...              ...           ...            ...       ...        ...
# 54545      Brazilian        Brazil             12  Defender        185
# 54553     Senegalese       Senegal             11  Defender        185
# 54565     Senegalese       Senegal             12  Defender        183
# 54582          Iraqi          Iraq             12  Defender        184
# 54585          Iraqi          Iraq             11  Defender        187
#
#        weight_kg preferred_foot
# 17            80           Left
# 22            80          Right
# ...

# %%
df2 =df.loc[(df['position']=='Defender') & (df['jersey_number']>10)].sort_values(by='jersey_number').tail(1)[['team']]
df2
# Out:
#           team
# 54472  Senegal

# %% [markdown]
# merge()

# %%
df1 = pd.DataFrame({
    'empid': [101,102,103,104,105],
    'empname' : ['anand','bavish','catherine','davis','ellas'],
    'designation' : ['doctor','engineer','advocate','teacher','developer']})
df1
# Out:
#    empid    empname designation
# 0    101      anand      doctor
# 1    102     bavish    engineer
# 2    103  catherine    advocate
# 3    104      davis     teacher
# 4    105      ellas   developer

# %%
df2 =pd.DataFrame({
    'empid': [101,102,103,106,107],
    'salaray' :[20000,203000,30000,28000,22000],
    'location':['ekm','kollam','kottayam','aluva','thrissur']})
df2
# Out:
#    empid  salaray  location
# 0    101    20000       ekm
# 1    102   203000    kollam
# 2    103    30000  kottayam
# 3    106    28000     aluva
# 4    107    22000  thrissur

# %%
df =pd.merge(df1,df2,how='inner',on='empid')
df
# Out:
#    empid    empname designation  salaray  location
# 0    101      anand      doctor    20000       ekm
# 1    102     bavish    engineer   203000    kollam
# 2    103  catherine    advocate    30000  kottayam

# %%
df = pd.merge(df1,df2,how='outer',on='empid')
df
# Out:
#    empid    empname designation   salaray  location
# 0    101      anand      doctor   20000.0       ekm
# 1    102     bavish    engineer  203000.0    kollam
# 2    103  catherine    advocate   30000.0  kottayam
# 3    104      davis     teacher       NaN       NaN
# 4    105      ellas   developer       NaN       NaN
# 5    106        NaN         NaN   28000.0     aluva
# 6    107        NaN         NaN   22000.0  thrissur

# %%
df = pd.merge(df1,df2,how='left',on='empid')
df
# Out:
#    empid    empname designation   salaray  location
# 0    101      anand      doctor   20000.0       ekm
# 1    102     bavish    engineer  203000.0    kollam
# 2    103  catherine    advocate   30000.0  kottayam
# 3    104      davis     teacher       NaN       NaN
# 4    105      ellas   developer       NaN       NaN

# %%
df = pd.merge(df1,df2,how='right',on='empid')
df
# Out:
#    empid    empname designation  salaray  location
# 0    101      anand      doctor    20000       ekm
# 1    102     bavish    engineer   203000    kollam
# 2    103  catherine    advocate    30000  kottayam
# 3    106        NaN         NaN    28000     aluva
# 4    107        NaN         NaN    22000  thrissur

# %%
df.dtypes
# Out:
# empid          int64
# empname          str
# designation      str
# salaray        int64
# location         str
# dtype: object

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
#change datatype of empid (to float)
df['empid']=df['empid'].astype('float')

# %%
df.dtypes
# Out:
# empid          float64
# empname            str
# designation        str
# salaray          int64
# location           str
# dtype: object
