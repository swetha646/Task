# %%
import pandas as pd

# %%
df = pd.DataFrame({
    "Emp_ID":[101,102,103,104,105],
    "Name":["John","Sara","Alex","Mary","David"],
    "Department":["HR","IT","HR","Sales","IT"],
    "Salary":[35000,50000,42000,60000,48000]
})
df
# Out:
#    Emp_ID   Name Department  Salary
# 0     101   John         HR   35000
# 1     102   Sara         IT   50000
# 2     103   Alex         HR   42000
# 3     104   Mary      Sales   60000
# 4     105  David         IT   48000

# %%
df.loc[df["Salary"]>42000]
# Out:
#    Emp_ID   Name Department  Salary
# 1     102   Sara         IT   50000
# 3     104   Mary      Sales   60000
# 4     105  David         IT   48000

# %%
df.sort_values(by ="Name")
# Out:
#    Emp_ID   Name Department  Salary
# 2     103   Alex         HR   42000
# 4     105  David         IT   48000
# 0     101   John         HR   35000
# 3     104   Mary      Sales   60000
# 1     102   Sara         IT   50000

# %%
df.sort_values(by ="Salary",ascending = False).head(1)
# Out:
#    Emp_ID  Name Department  Salary
# 3     104  Mary      Sales   60000

# %%
df["Bonus"] = df['Salary'] * 0.10
print(df)
# Out:
#    Emp_ID   Name Department  Salary   Bonus
# 0     101   John         HR   35000  3500.0
# 1     102   Sara         IT   50000  5000.0
# 2     103   Alex         HR   42000  4200.0
# 3     104   Mary      Sales   60000  6000.0
# 4     105  David         IT   48000  4800.0
